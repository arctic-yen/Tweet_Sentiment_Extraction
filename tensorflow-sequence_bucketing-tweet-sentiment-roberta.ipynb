# %%
import math
import glob
import sys
import random
import gc
import os
import re
from math import floor, ceil

import pandas as pd
import numpy as np
#TF&K
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import initializers, regularizers, constraints, optimizers, layers, losses, models, callbacks
from tensorflow.keras.initializers import *
from tensorflow.keras.regularizers import *
from tensorflow.keras.constraints import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
print(tf.__version__)

from sklearn.model_selection import StratifiedKFold
from transformers import *
import tokenizers

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2.1.0

# %%
def seed_everything(framework,SEED):
    random.seed(SEED)
    os.environ["PYTHONHASHSEED"] = str(SEED)
    if framework == 'Pytorch':
        torch.manual_seed(SEED)
        torch.cuda.manual_seed(SEED)
    elif framework == 'Tensorflow':
        tf.random.set_seed(SEED)
        
framework = 'Tensorflow'
SEED = 88888
seed_everything(framework, SEED)

# %%
MAX_LEN = 96
PATH = '../input/tf-roberta/'
tokenizer = tokenizers.ByteLevelBPETokenizer(
    vocab_file=PATH+'vocab-roberta-base.json', 
    merges_file=PATH+'merges-roberta-base.txt', 
    lowercase=True,
    add_prefix_space=True
)
EPOCHS = 3
BATCH_SIZE = 32
PAD_ID = 1
LABEL_SMOOTHING = 0.1
sentiment_id = {'positive': 1313, 'negative': 2430, 'neutral': 7974}

# %%
train = pd.read_csv('../input/tweet-sentiment-extraction/train.csv').fillna('')
ct = train.shape[0]
input_ids = np.ones((ct,MAX_LEN),dtype='int32')
attention_mask = np.zeros((ct,MAX_LEN),dtype='int32')
token_type_ids = np.zeros((ct,MAX_LEN),dtype='int32')
start_tokens = np.zeros((ct,MAX_LEN),dtype='int32')
end_tokens = np.zeros((ct,MAX_LEN),dtype='int32')

for k in range(train.shape[0]):
    
    # FIND OVERLAP
    text1 = " "+" ".join(train.loc[k,'text'].split())
    text2 = " ".join(train.loc[k,'selected_text'].split())
    idx = text1.find(text2)
    chars = np.zeros((len(text1)))
    chars[idx:idx+len(text2)]=1
    if text1[idx-1]==' ': chars[idx-1] = 1 
    enc = tokenizer.encode(text1) 
        
    # ID_OFFSETS
    offsets = []; idx=0
    for t in enc.ids:
        w = tokenizer.decode([t])
        offsets.append((idx,idx+len(w)))
        idx += len(w)
    
    # START END TOKENS
    toks = []
    for i,(a,b) in enumerate(offsets):
        sm = np.sum(chars[a:b])
        if sm>0: toks.append(i) 
        
    s_tok = sentiment_id[train.loc[k,'sentiment']]
    input_ids[k,:len(enc.ids)+3] = [0, s_tok] + enc.ids + [2]
    attention_mask[k,:len(enc.ids)+3] = 1
    if len(toks)>0:
        start_tokens[k,toks[0]+2] = 1
        end_tokens[k,toks[-1]+2] = 1

# %%
test = pd.read_csv('../input/tweet-sentiment-extraction/test.csv').fillna('')

ct = test.shape[0]
input_ids_t = np.ones((ct,MAX_LEN),dtype='int32')
attention_mask_t = np.zeros((ct,MAX_LEN),dtype='int32')
token_type_ids_t = np.zeros((ct,MAX_LEN),dtype='int32')

for k in range(test.shape[0]):
        
    # INPUT_IDS
    text1 = " "+" ".join(test.loc[k,'text'].split())
    enc = tokenizer.encode(text1)                
    s_tok = sentiment_id[test.loc[k,'sentiment']]
    input_ids_t[k,:len(enc.ids)+3] = [0, s_tok] + enc.ids + [2]
    attention_mask_t[k,:len(enc.ids)+3] = 1

# %%
import pickle

def save_weights(model, dst_fn):
    weights = model.get_weights()
    with open(dst_fn, 'wb') as f:
        pickle.dump(weights, f)


def load_weights(model, weight_fn):
    with open(weight_fn, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)
    return model

# %%
def loss_fn(y_true, y_pred):
    # adjust the targets for sequence bucketing
    ll = tf.shape(y_pred)[1]
    y_true = y_true[:, :ll]
    loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred,
        from_logits=False, label_smoothing=LABEL_SMOOTHING)
    loss = tf.reduce_mean(loss)
    return loss

def scheduler(epoch):
    return 3e-5 * 0.2**epoch

lrate = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

def build_model():
    ids = tf.keras.layers.Input((MAX_LEN,), dtype=tf.int32)
    att = tf.keras.layers.Input((MAX_LEN,), dtype=tf.int32)
    tok = tf.keras.layers.Input((MAX_LEN,), dtype=tf.int32)
    padding = tf.cast(tf.equal(ids, PAD_ID), tf.int32)

    lens = MAX_LEN - tf.reduce_sum(padding, -1)
    max_len = tf.reduce_max(lens)
    ids_ = ids[:, :max_len]
    att_ = att[:, :max_len]
    tok_ = tok[:, :max_len]

    config = RobertaConfig.from_pretrained(PATH+'config-roberta-base.json')
    #config.output_hidden_states = True
    bert_model = TFRobertaModel.from_pretrained(PATH+'pretrained-roberta-base.h5',config=config)
    x = bert_model(ids_,attention_mask=att_,token_type_ids=tok_)
    
    x1 = tf.keras.layers.Dropout(0.1)(x[0]) 
    x1 = tf.keras.layers.Conv1D(128, 3,padding='same')(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Conv1D(64, 3,padding='same')(x1)
    x1 = tf.keras.layers.Dense(1)(x1)
    x1 = tf.keras.layers.Flatten()(x1)
    x1 = tf.keras.layers.Activation('softmax')(x1)
    
    x2 = tf.keras.layers.Dropout(0.1)(x[0]) 
    x2 = tf.keras.layers.Conv1D(128, 3, padding='same')(x2)
    x2 = tf.keras.layers.LeakyReLU()(x2)
    x2 = tf.keras.layers.Conv1D(64, 3, padding='same')(x2)
    x2 = tf.keras.layers.Dense(1)(x2)
    x2 = tf.keras.layers.Flatten()(x2)
    x2 = tf.keras.layers.Activation('softmax')(x2)
    
    model = tf.keras.models.Model(inputs=[ids, att, tok], outputs=[x1,x2])
    optimizer = tf.keras.optimizers.Adam(learning_rate=3e-5) 
    model.compile(loss=loss_fn, optimizer=optimizer)
    
    # this is required as `model.predict` needs a fixed size!
    x1_padded = tf.pad(x1, [[0, 0], [0, MAX_LEN - max_len]], constant_values=0.)
    x2_padded = tf.pad(x2, [[0, 0], [0, MAX_LEN - max_len]], constant_values=0.)
    
    padded_model = tf.keras.models.Model(inputs=[ids, att, tok], outputs=[x1_padded,x2_padded])
    return model, padded_model

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    if (len(a)==0) & (len(b)==0): return 0.5
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
jac = []; VER='v2'; DISPLAY=1 # USE display=1 FOR INTERACTIVE
oof_start = np.zeros((input_ids.shape[0],MAX_LEN))
oof_end = np.zeros((input_ids.shape[0],MAX_LEN))
preds_start = np.zeros((input_ids_t.shape[0],MAX_LEN))
preds_end = np.zeros((input_ids_t.shape[0],MAX_LEN))

skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=SEED)
for fold,(idxT,idxV) in enumerate(skf.split(input_ids,train.sentiment.values)):

    print('#'*25)
    print('### FOLD %i'%(fold+1))
    print('#'*25)
    
    K.clear_session()
    model, padded_model = build_model()
        
    #sv = tf.keras.callbacks.ModelCheckpoint(
    #    '%s-roberta-%i.h5'%(VER,fold), monitor='val_loss', verbose=1, save_best_only=True,
    #    save_weights_only=True, mode='auto', save_freq='epoch')
    es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', patience=2, 
                                          restore_best_weights=True, verbose=1)
    inpT = [input_ids[idxT,], attention_mask[idxT,], token_type_ids[idxT,]]
    targetT = [start_tokens[idxT,], end_tokens[idxT,]]
    inpV = [input_ids[idxV,],attention_mask[idxV,],token_type_ids[idxV,]]
    targetV = [start_tokens[idxV,], end_tokens[idxV,]]
    # sort the validation data
    shuffleV = np.int32(sorted(range(len(inpV[0])), key=lambda k: (inpV[0][k] == PAD_ID).sum(), reverse=True))
    inpV = [arr[shuffleV] for arr in inpV]
    targetV = [arr[shuffleV] for arr in targetV]
    weight_fn = '%s-sequence-bucketing-roberta-%i.h5'%(VER,fold)
    for epoch in range(1, EPOCHS + 1):
        # sort and shuffle: We add random numbers to not have the same order in each epoch
        shuffleT = np.int32(sorted(range(len(inpT[0])), key=lambda k: (inpT[0][k] == PAD_ID).sum() + np.random.randint(-3, 3), reverse=True))
        # shuffle in batches, otherwise short batches will always come in the beginning of each epoch
        num_batches = math.ceil(len(shuffleT) / BATCH_SIZE)
        batch_inds = np.random.permutation(num_batches)
        shuffleT_ = []
        for batch_ind in batch_inds:
            shuffleT_.append(shuffleT[batch_ind * BATCH_SIZE: (batch_ind + 1) * BATCH_SIZE])
        shuffleT = np.concatenate(shuffleT_)
        # reorder the input data
        inpT = [arr[shuffleT] for arr in inpT]
        targetT = [arr[shuffleT] for arr in targetT]
        model.fit(inpT, targetT, 
            epochs=epoch, initial_epoch=epoch - 1, batch_size=BATCH_SIZE, verbose=DISPLAY, callbacks=[lrate,es],
            validation_data=(inpV, targetV), shuffle=False)  # don't shuffle in `fit`
        save_weights(model, weight_fn)

    print('Loading model...')
    # model.load_weights('%s-roberta-%i.h5'%(VER,fold))
    load_weights(model, weight_fn)

    print('Predicting OOF...')
    oof_start[idxV,],oof_end[idxV,] = padded_model.predict([input_ids[idxV,],attention_mask[idxV,],token_type_ids[idxV,]],verbose=DISPLAY)
    
    print('Predicting Test...')
    preds = padded_model.predict([input_ids_t,attention_mask_t,token_type_ids_t],verbose=DISPLAY)
    preds_start += preds[0]/skf.n_splits
    preds_end += preds[1]/skf.n_splits
    
    # DISPLAY FOLD JACCARD
    all = []
    for k in idxV:
        a = np.argmax(oof_start[k,])
        b = np.argmax(oof_end[k,])
        text1 = " "+" ".join(train.loc[k,'text'].split())
        
        if train.loc[k,'sentiment'] == 'neutral':
            if a>b:
                st = train.loc[k,'text']
            else:
                enc = tokenizer.encode(text1)
                st = tokenizer.decode(enc.ids[a-2:b-1])
        else:
            if a>b:
                print('index :' + str(k))
                print('text :' + train.loc[k,'text'])
                print('selected_text :' + train.loc[k,'selected_text'])
                st_a , st_b = '' , ''
                start_sort = np.argsort(oof_start[k,])[::-1] 
                end_sort = np.argsort(oof_end[k,])[::-1]
                a1 = start_sort[1]
                b1 = end_sort[1]
                a2 = start_sort[2]
                b2 = end_sort[2]
                #print('a: ' + str(a) + ' a proba: ' + str(oof_start[k,][a]) + '\na1: ' + str(a1) + ' a1 proba: ' + str(oof_start[k,][a1]) + '\na2: '+ str(a2) + ' a2 proba: ' + str(oof_start[k,][a2]))
                #print('b: ' + str(b) + ' b proba: ' + str(oof_end[k,][b]) + '\nb1: ' + str(b1) + ' b1 proba: ' + str(oof_end[k,][b1]) + '\nb2: '+ str(b2) + ' b2 proba: ' + str(oof_end[k,][b2]))
                
                if a1 < b:
                    enc = tokenizer.encode(text1)
                    st_a = tokenizer.decode(enc.ids[a1-2:b-1])
                    #print('model_select a1<b :' + st_a)
                elif a2 < b:
                    enc = tokenizer.encode(text1)
                    st_a = tokenizer.decode(enc.ids[a2-2:b-1])
                    #print('model_select a2<b :' + st_a)
                    
                if a < b1:
                    enc = tokenizer.encode(text1)
                    st_b = tokenizer.decode(enc.ids[a-2:b1-1])
                    #print('model_select a<b1 :' + st_b)
                elif a1 < b1:
                    enc = tokenizer.encode(text1)
                    st_b = tokenizer.decode(enc.ids[a1-2:b1-1])
                    #print('model_select a1<b1 :' + st_b)
                    
                st = st_a + ' ' + st_b
                print('model_select :' + st)
                if len(st.split()) == 0:
                    st = train.loc[k,'text']

            else:
                enc = tokenizer.encode(text1)
                st = tokenizer.decode(enc.ids[a-2:b-1])
            st = st.replace('!!!!', '!') if len(st.split())==1 else st
            st = st.replace('..', '.') if len(st.split())==1 else st
            st = st.replace('...', '.') if len(st.split())==1 else st
        all.append(jaccard(st,train.loc[k,'selected_text']))
        #a = np.argmax(oof_start[k,])
        #b = np.argmax(oof_end[k,])
        #if a>b: 
        #    st = train.loc[k,'text'] # IMPROVE CV/LB with better choice here
        #else:
        #    text1 = " "+" ".join(train.loc[k,'text'].split())
        #    enc = tokenizer.encode(text1)
        #    st = tokenizer.decode(enc.ids[a-2:b-1])
        #all.append(jaccard(st,train.loc[k,'selected_text']))
    jac.append(np.mean(all))
    print('>>>> FOLD %i Jaccard ='%(fold+1),np.mean(all))
    print()
# Out:
# #########################
# ### FOLD 1
# #########################
# Train on 21984 samples, validate on 5497 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3e-05.
# 21984/21984 [==============================] - 131s 6ms/sample - loss: 2.8613 - activation_loss: 1.4323 - activation_1_loss: 1.4290 - val_loss: 2.5594 - val_activation_loss: 1.2953 - val_activation_1_loss: 1.2653
# Train on 21984 samples, validate on 5497 samples
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 6e-06.
# Epoch 2/2
# 21984/21984 [==============================] - 104s 5ms/sample - loss: 2.4738 - activation_loss: 1.2594 - activation_1_loss: 1.2144 - val_loss: 2.5111 - val_activation_loss: 1.2684 - val_activation_1_loss: 1.2440
# Train on 21984 samples, validate on 5497 samples
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.2000000000000004e-06.
# Epoch 3/3
# 21984/21984 [==============================] - 103s 5ms/sample - loss: 2.4060 - activation_loss: 1.2261 - activation_1_loss: 1.1799 - val_loss: 2.5013 - val_activation_loss: 1.2633 - val_activation_1_loss: 1.2392
# Loading model...
# Predicting OOF...
# 5497/5497 [==============================] - 16s 3ms/sample
# Predicting Test...
# 3534/3534 [==============================] - 8s 2ms/sample
# index :407
# text : yep infact she is popular, miss india 99, talented film actress .... and lot more
# selected_text :she is popular,
# model_select : popular,  popular, miss india 99, talented
# index :2187
# text :New work wellness challenge not going well.  I committed to not check email between 10 pm and 6 am.  Failed on first day.  Twice
# selected_text :Failed on first day.  Twic
# model_select : not going well.  not going well. i committed to not check email between 10 pm and 6 am. failed
# index :3891
# text :Aaarrrgh! I sooo want to see  at MSG in August but dammit the decent seats are expensive. Booooooo recession!
# selected_text :expensive.
# model_select : aaarrrgh!  dammit
# index :4618
# text :If someone in the family died you would of heard about it. Duhhhhhh. . .
# selected_text :Duhhhhhh.
# model_select : if someone in the family died  duhhhhhh.
# index :4716
# text :Another loser: ****. I have lost the game more times today than any other day in history.  lost.. http://tinyurl.com/qa4cdv ( ...
# selected_text :Another loser: ****.
# model_select : another loser: ****.  another loser: ****. i have lost
# index :7916
# text :btw. ear is getting better! its about time! finally - i say goodnight twitter world, (even though y`all are already asleep). xoxo
# selected_text :better!
# model_select : better!  goodnight
# index :7960
# text :Found out I have to go to the US again in August. Getting tired of transatlantic flights. Not good for my carbon footprint either
# selected_text :Getting tired of transatlantic flights. Not good for my carbon footprint either
# model_select : getting tired  not good for my carbon footprint either
# index :8409
# text :is very very tired  just want to sleep.  Stupid work getting in the way!!!
# selected_text :Stupid work
# model_select : is very very tired  stupid work getting in the way!!!
# index :11398
# text :Photo: hannahisdead: omg i wanna read Pride and prejudice and zombies fuckyeah zombies  http://tumblr.com/xol1qyw8v
# selected_text :hannahisdead:
# model_select : omg i wanna read pride and prejudice  fuckyeah zombies
# index :12433
# text : hahaha wow thanks bud :p but my plan is to pretend its a costume... I wish it were cold so i could wear a sweatshirt over this
# selected_text :thanks
# model_select : wow thanks  wow thanks bud
# index :12876
# text :o/*\o (high five) to all of our fans! It`s finally here! I`ll write up a fancy news post shortly, wanted to get the mod itself out ASAP
# selected_text :(high five) to all of our fans!
# model_select : (high five) to all of our fans!  (high five)
# index :17531
# text :Math class ugh.  Rather be a class act.  **** quiz   gotta act fast
# selected_text :Math class ugh.  Rather be a class act.  **** quiz   gotta act fa
# model_select : ugh.  **** quiz gotta act fast
# index :20327
# text :It worked. Cool AND the gang!
# selected_text :Cool
# model_select : it worked.  cool and the gang!
# index :27167
# text :i just looove my bf  u are awesoome!!!! [hannah montana the movie was amazing  best movie ever!!]  // cool http://gykd.net
# selected_text :awesoome!
# model_select : i just looove my bf u are awesoome!!!!  i just looove my bf u are awesoome!!!! [hannah montana the movie was amazing
# >>>> FOLD 1 Jaccard = 0.7096777971288136
#
# #########################
# ### FOLD 2
# #########################
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3e-05.
# 21985/21985 [==============================] - 130s 6ms/sample - loss: 2.9005 - activation_loss: 1.4494 - activation_1_loss: 1.4483 - val_loss: 2.5122 - val_activation_loss: 1.2780 - val_activation_1_loss: 1.2353
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 6e-06.
# Epoch 2/2
# 21985/21985 [==============================] - 105s 5ms/sample - loss: 2.4888 - activation_loss: 1.2637 - activation_1_loss: 1.2229 - val_loss: 2.4687 - val_activation_loss: 1.2552 - val_activation_1_loss: 1.2147
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.2000000000000004e-06.
# Epoch 3/3
# 21985/21985 [==============================] - 114s 5ms/sample - loss: 2.4740 - activation_loss: 1.2582 - activation_1_loss: 1.2149 - val_loss: 2.4733 - val_activation_loss: 1.2579 - val_activation_1_loss: 1.2167
# Loading model...
# Predicting OOF...
# 5496/5496 [==============================] - 17s 3ms/sample
# Predicting Test...
# 3534/3534 [==============================] - 9s 2ms/sample
# index :3151
# text :I always get really excited when `Steal My Kisses` by Ben Harper comes on the ipod...great song...love the beat-boxing in the beginning
# selected_text :excited
# model_select : great song...
# index :4326
# text : this is funny, we just discussed Bela Lugosi  over dinner, his apearance in Plan B from outer space 'best' movie ever
# selected_text :this is funny,
# model_select : this is funny,  'best' movie ever
# index :5312
# text : lol sweet!!! ...i still have yet to watch the 4th movie  hope ur having a lovely weekend! happy mother`s day from aus! =P haha
# selected_text :hope ur having a lovely weekend!
# model_select : lol sweet!!!  lol sweet!!! ...i still have yet to watch the 4th movie hope ur having a lovely weekend! happy
# index :5561
# text :I just put my TV on the Canucks game and they score  yaay come on VanCity baby (I know, I can`t believe I`m watching hockey either)
# selected_text :yaay
# model_select : yaay  i can`t believe i`m watching hockey either)
# index :11328
# text :I do hope many of my new followers are from around Sydney Australia  Welcome to my tweets anyway.
# selected_text :hope
# model_select : i do hope  i do hope many of my new followers are from around sydney australia welcome
# index :15393
# text : Yay, so the nekkid writing is working then?You keep warm now! Am in awe of the 6k - am always cactus by 5. Good luck
# selected_text :Good luck
# model_select : am in awe  good luck
# index :17858
# text : ok cause the one  S orange is still open. Whew, you just scared me. Sorry the one by you closed
# selected_text :t scared
# model_select : you just scared  sorry the one by you closed
# index :19533
# text :2 days till birthday! I just hope the weathers good!! And it best be good on thursday and friday! Otherwise il scream! happy b`day keiron
# selected_text :I just hope the weathers good!! And it best be good on thursday and friday!
# model_select : hope the weathers good!!  happy b`day keiron
# index :22083
# text : Hi Lisa, you have the most BEAUTIFUL pups! HAPPY MOTHERS DAY!2 Raven, Rio& Thors WONDERFUR mama!!  *kittykisses*
# selected_text :Hi Lisa, you have the most BEAUTIFUL pups! HAPPY MOTHERS DAY!2 Raven, Rio& Thors WONDERFUR mama!!  *kittykisses*
# model_select : you have the most beautiful  happy mothers day!
# >>>> FOLD 2 Jaccard = 0.7205401777315689
#
# #########################
# ### FOLD 3
# #########################
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3e-05.
# 21985/21985 [==============================] - 134s 6ms/sample - loss: 2.9398 - activation_loss: 1.4689 - activation_1_loss: 1.4736 - val_loss: 2.5712 - val_activation_loss: 1.3022 - val_activation_1_loss: 1.2701
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 6e-06.
# Epoch 2/2
# 21985/21985 [==============================] - 109s 5ms/sample - loss: 2.5199 - activation_loss: 1.2785 - activation_1_loss: 1.2393 - val_loss: 2.4985 - val_activation_loss: 1.2545 - val_activation_1_loss: 1.2453
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.2000000000000004e-06.
# Epoch 3/3
# 21985/21985 [==============================] - 113s 5ms/sample - loss: 2.4744 - activation_loss: 1.2576 - activation_1_loss: 1.2151 - val_loss: 2.4931 - val_activation_loss: 1.2571 - val_activation_1_loss: 1.2371
# Loading model...
# Predicting OOF...
# 5496/5496 [==============================] - 16s 3ms/sample
# Predicting Test...
# 3534/3534 [==============================] - 9s 2ms/sample
# index :2806
# text :So bored... need more people for rsmv !!  jagex doesn`t let u say RSMV unless its the first word u say in the sentence.. sad
# selected_text :sad
# model_select : so bored...  so bored... need more people for rsmv !! jagex doesn`t let u say rsmv unless its the first word u say in the sentence.. sad
# index :5495
# text : if its too hard go to ur guy peicing person and he shoud change it cause mine be hard to change to
# selected_text :hard
# model_select : if its too hard  if its too hard go to ur guy peicing person and he shoud change it cause mine be hard
# index :6901
# text :I`m torn, do I get an extended warranty for my iPhone when mine runs out, or jailbreak? I`ve already got problems with battery & earpiece
# selected_text :I`ve already got problems with battery & earpiece
# model_select : i`m torn,  i`m torn, do i get an extended warranty for my iphone when mine runs out, or jailbreak? i`ve already got problems
# index :20222
# text : I can`t die  I have a lunch date with rocio coming up plus some new shoes UGH!
# selected_text :s UGH
# model_select : i can`t die  ugh!
# index :24243
# text :To make it worse, its my friends party tonight, and I`m stuck here. I haven`t seen her for months
# selected_text :worse,
# model_select : worse,  stuck here.
# index :24798
# text :Watching TV with the best people in the whole world !!!!! My Mum and My Sis Agus (: Love you all ! Twitter you later ha
# selected_text :Love
# model_select : watching tv with the best  best people in the whole world !!!!! my mum and my sis agus (: love
# index :25419
# text :Really enjoyed Star Trek - great movie, amazing special effects. Definately recommend even if your not a Trekky
# selected_text :Really enjoyed Star Trek - great movie, amazing special effects. Definately recommend
# model_select : really enjoyed  really enjoyed star trek - great
# >>>> FOLD 3 Jaccard = 0.7108880016902843
#
# #########################
# ### FOLD 4
# #########################
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3e-05.
# 21985/21985 [==============================] - 135s 6ms/sample - loss: 2.9079 - activation_loss: 1.4547 - activation_1_loss: 1.4527 - val_loss: 2.5685 - val_activation_loss: 1.3142 - val_activation_1_loss: 1.2564
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 6e-06.
# Epoch 2/2
# 21985/21985 [==============================] - 111s 5ms/sample - loss: 2.5188 - activation_loss: 1.2772 - activation_1_loss: 1.2412 - val_loss: 2.5209 - val_activation_loss: 1.2919 - val_activation_1_loss: 1.2310
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.2000000000000004e-06.
# Epoch 3/3
# 21985/21985 [==============================] - 110s 5ms/sample - loss: 2.4505 - activation_loss: 1.2425 - activation_1_loss: 1.2059 - val_loss: 2.5264 - val_activation_loss: 1.2944 - val_activation_1_loss: 1.2340
# Loading model...
# Predicting OOF...
# 5496/5496 [==============================] - 17s 3ms/sample
# Predicting Test...
# 3534/3534 [==============================] - 8s 2ms/sample
# index :996
# text : my sleep pattern is screwed i need to try and stay up 2 midnight so i can get some decent sleep coz i havent slept
# selected_text :my sleep pattern is screwed
# model_select : my sleep pattern is screwed  decent sleep
# index :3094
# text : hope you had a FAB time!!! Just saw your twitpics ... Love that you wore THE dress. Great pic of D too
# selected_text :hope
# model_select : hope you had a fab time!!!  hope you had a fab
# index :3623
# text :: I know!! Im so excited. We cant go earlierrr than the afternoon?  I love you tooz <3
# selected_text :Im so excited. We cant go earlierrr than the afternoon?  I love you tooz
# model_select : im so excited.  i love
# index :7040
# text :Also with the not driving part i could afford a laptop. Also living with a roommate i would save even more
# selected_text :save ev
# model_select :  i would save
# index :8222
# text :Very bored. All day, no one 2 talk 2. Missing my BF (and his kisses). Hols almost over,  don`t wanna go back 2 skool.
# selected_text :Very bored. All day, no one 2 talk 2. Missing my BF (and his kisses).
# model_select : very bored.  very bored. all day, no one 2 talk 2. missing
# index :8299
# text : o_O thats cool. Dang, iHave to clean my room now  lol, but good luck w/those jobs gurl
# selected_text :t good
# model_select : thats cool.  good luck w/those jobs gurl
# index :10842
# text :a surprisingly good day, now its time to sleep. hopefully sweet dreams await me
# selected_text :a surprisingly good day,
# model_select : good day,
# index :10853
# text : Hii,I freaking love you  I would be the happiest 13 year old girl alive if you replied to this.
# selected_text :I freaking love
# model_select : love you  love you i would be the happiest
# index :11056
# text : I need them  It would`ve made my picture so much cooler. Mine are bottle green. Eeyea-thooo!
# selected_text :I need them  It would`ve made my picture so much cooler
# model_select : cooler.  eeyea-thooo!
# index :17023
# text : definitely dont be offended. im messing around with various twitter apps and strange things keep happening.
# selected_text :. im messing around
# model_select : definitely dont be offended.  strange things keep happening.
# index :20486
# text :yay, just got my stuff from rygegrej.dk  Perfect tastes like banana and apple
# selected_text :Perfect
# model_select : yay,  yay, just got my stuff from rygegrej.dk perfect
# index :23930
# text : hello  i am ur biggest fan, and i rly carnt w8 till new moon comes out! good luck 2 u nd all the cast filming  ****
# selected_text :! good luck
# model_select : hello i am ur biggest fan,  good luck
# index :25228
# text : You got it! YAAAY!!! I was really worried your phone wouldn`t fit, so glad it does!  Happy Mother`s Day, lol!
# selected_text :YAAAY!
# model_select : so glad  glad it does! happy
# >>>> FOLD 4 Jaccard = 0.707352406599804
#
# #########################
# ### FOLD 5
# #########################
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3e-05.
# 21985/21985 [==============================] - 138s 6ms/sample - loss: 2.9580 - activation_loss: 1.4750 - activation_1_loss: 1.4816 - val_loss: 2.5548 - val_activation_loss: 1.3046 - val_activation_1_loss: 1.2515
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 6e-06.
# Epoch 2/2
# 21985/21985 [==============================] - 113s 5ms/sample - loss: 2.5352 - activation_loss: 1.2854 - activation_1_loss: 1.2481 - val_loss: 2.4938 - val_activation_loss: 1.2721 - val_activation_1_loss: 1.2232
# Train on 21985 samples, validate on 5496 samples
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.2000000000000004e-06.
# Epoch 3/3
# 21985/21985 [==============================] - 106s 5ms/sample - loss: 2.4250 - activation_loss: 1.2307 - activation_1_loss: 1.1938 - val_loss: 2.4955 - val_activation_loss: 1.2736 - val_activation_1_loss: 1.2234
# Loading model...
# Predicting OOF...
# 5496/5496 [==============================] - 17s 3ms/sample
# Predicting Test...
# 3534/3534 [==============================] - 8s 2ms/sample
# index :2678
# text :_Mcfly how cool will that be  she is so nice!! Bless her=] so what ya upto? Love you (L) XoxoX
# selected_text :how cool will that be  she is so nice!!
# model_select : she is so nice!!  love you
# index :8459
# text :_I Yeah poor Yao! Hope u had fun looking at the Lakers JerseyZ haha! Enjoy ur time buddy !
# selected_text :Enjoy
# model_select : hope u had fun  hope u had fun looking at the lakers jerseyz haha! enjoy
# index :8755
# text :Today`s ABA has been full of emotional tears  #ASD #autism some days are harder than others.  Its hard to not intervene  poor baby
# selected_text :some days are harder than others.
# model_select :  harder than others. its hard to not intervene poor baby
# index :9413
# text :Help. My computer has a virus. I had to place my Etsy shop into vacation mode until I can sort this out. I don`t know WHAT to do!
# selected_text :virus.
# model_select : virus.  i don`t know what to do!
# index :11214
# text : that`s cool! i think del`s going to korea same time as you! have fun!
# selected_text :that`s cool! i think del`s going to korea same time as you! have fun!
# model_select : that`s cool!  have fun!
# index :11923
# text :gasp-- 10 followers! i feel almost famous. i used to think i would be famous when i grew up one day LOL. oh well, cheers to norm peeps!
# selected_text :cheers
# model_select : famous.  famous. i used to think i would be famous when i grew up one day lol. oh well, cheers
# index :13445
# text : Presentation went well  Yes, I also met a buch of cool people. Checked your portfolio, nice work/details in the projects.
# selected_text :h of cool people. Checked your portfolio, nice work/details in the project
# model_select : presentation went well yes, i also met a buch of cool  cool people. checked your portfolio, nice
# index :15332
# text :feeling really sick  watching the fifth element, and about to smoke a cigg. ugh i hate colds!
# selected_text :feeling really sick
# model_select : feeling really sick  ugh i hate colds!
# index :16049
# text :I`m feeling pretty energized & ready to face the day w/only about 3 hours of sleep. Hope it lasts all day.
# selected_text :feeling pretty energized
# model_select : i`m feeling pretty energized  i`m feeling pretty energized & ready to face the day w/only about 3 hours of sleep. hope
# index :17082
# text : Wow, that`s really sweet! I`m assuming this is blog-related.  Thanks so much.
# selected_text :really sweet!
# model_select : wow, that`s really sweet!  thanks so much.
# index :18082
# text : my computers broken and I broke my laptop so I had to use the phone  ahh still on he cause they **** up my order.
# selected_text :broken
# model_select : my computers broken  **** up my order.
# index :18593
# text :Gave my mommy her Mother`s Day present. Tickets to Aerosmith (her favorite band everr.) Yay for a good reaction.
# selected_text :good
# model_select :  good reaction.
# index :19558
# text :_Da_Realest hehe hell. I`m finna qet to drankin DAMNIT.
# selected_text :DAMNIT.
# model_select : hell.  damnit.
# index :20948
# text : Yvonne, thanks 4 the #FFrecommend! Lovely profile photo, you have! And I agree w/u on the 'what is sleep?'  LOL! It`s 5:46 am!
# selected_text :Lovely profile photo,
# model_select : yvonne, thanks  thanks 4 the #ffrecommend! lovely
# index :21231
# text :http://twitpic.com/67nxe - Yeah..I`m bored XD I pic up this photo when I still have my guitar..today my mum steam me it  I miss Nameless..
# selected_text :miss
# model_select : yeah..i`m bored  i miss
# index :21369
# text : ooo thanks for the danger radio link  loves it...how did the test go?
# selected_text :ooo thanks for the danger radio link  loves it..
# model_select : ooo thanks  loves it...
# index :23376
# text : LOL - Birmingham was my 1st love... but it`s time to move on! ;) Good Morning
# selected_text :Birmingham was my 1st love.
# model_select : love...  good morning
# index :25530
# text : yeah exactly the fans overpower the haters anyday u know wat do wat u wnt i dnt even care anymore i know the truth about them
# selected_text :t i dnt even care anymore
# model_select : overpower the haters  i dnt even care anymore
# index :26035
# text :Well. That first tweet for today failed.  lol. Back to sleep or bacon and eggs? So hard to choose!!
# selected_text :So hard to choose!!
# model_select : failed.  so hard to choose!!
# index :26495
# text : Hahahaha! It`s not horrible, if others were singing with I`m sure it could work. I wish I could afford my own drum set
# selected_text :not horrible,
# model_select : it`s not horrible,  i wish
# >>>> FOLD 5 Jaccard = 0.7072035540222091

# %%
print(jac)
print('>>>> OVERALL 5Fold CV Jaccard =',np.mean(jac))
# Out:
# [0.7096777971288136, 0.7205401777315689, 0.7108880016902843, 0.707352406599804, 0.7072035540222091]
# >>>> OVERALL 5Fold CV Jaccard = 0.7111323874345359

# %%
all = []
for k in range(input_ids_t.shape[0]):
    a = np.argmax(preds_start[k,])
    b = np.argmax(preds_end[k,])
    if a>b: 
        st = test.loc[k,'text']
    else:
        text1 = " "+" ".join(test.loc[k,'text'].split())
        enc = tokenizer.encode(text1)
        st = tokenizer.decode(enc.ids[a-2:b-1])
    all.append(st)

# %%
test['selected_text'] = all
test['selected_text'] = test['selected_text'].apply(lambda x: x.replace('!!!!', '!') if len(x.split())==1 else x)
test['selected_text'] = test['selected_text'].apply(lambda x: x.replace('..', '.') if len(x.split())==1 else x)
test['selected_text'] = test['selected_text'].apply(lambda x: x.replace('...', '.') if len(x.split())==1 else x)
test[['textID','selected_text']].to_csv('submission.csv',index=False)
pd.set_option('max_colwidth', 60)
test.sample(25)
# Out:
#           textID                                                         text  \
# 1080  a2819eaa7a  we`ll be visiting my grandparents later. BTW i just hear...
# 940   261a5bbd14   tell me what you think of Pride Prejudice and Zombies ....
# 2826  769c8775bf   so technically....i havent really gotten out of bed. so...
# 1993  204d6510c6                        **** awake at 2 am !  i hate sickness
# 416   e892068fd3       lol that just totally made me laugh, which made my day
# 2332  43ee369d34  Following new other #sanctuary fans! See the wonders of ...
# 1483  9932b9c033  if i wasnt workin in 5 hours id be gettin ratarsed to th...
# 1240  2cd5a21fbc                                    Sending blessings out to
# 2443  1c5ca67cf9   Good Grief! I can`t say much, I was driving home from M...
# 3025  6030362588             _flo well thats not nice... hope ur all good now
# 143   3f90f95beb   why would they take a photo with stuffed animals?! that...
# 248   5a91b175f6                                                  , goodnight
# 2265  5acf4885d4  omg having so much fun watcing house bunny, courto isa a...
# 875   0182dd7de1  Discovered that Numpy arrays can hold values of any type...
# 1219  cea5b3f191  Best friend is leaving to go back to school today..I am ...
# 2837  06ed7a838d           got the twilight board game today  good old ebay..
# 413   481e268403   I know.  I am definitely going to try and see Up this w...
# 2477  cd00966e36  Just watched hella home movies with my aunt and uncle. I...
# 1701  49a1fc4061                                 welcome to twitter my friend
# 1089  f97b498af4   you should come to Estonia, I know some epic horses her...
# 2850  6fe5a83801  seagull hates me and im utterly depressed about it. i mi...
# 1359  05810a7cdd   He loved it, so Happy Birthday!!!   He said you sounded...
# 1083  c0abd616ab   I`m sure she`ll be fine. They`re not as daft as they lo...
# 494   1b1243d0b5  Gha, off to work - hopefully traffic has cleared up by t...
# 1728  2fadf73014  Still feeling weird about my ex and her engagement.  My ...
#
#      sentiment                                                selected_text
# 1080  positive                                          whew so cool i love
# 940    neutral   tell me what you think of pride prejudice and zombies ....
# 2826   neutral   so technically....i havent really gotten out of bed. so...
# 1993  negative                                              i hate sickness
# 416   positive                                                       laugh,
# 2332  positive                                                         good
# 1483  negative                                                  **** i feel
# 1240  positive                                            sending blessings
# 2443   neutral   good grief! i can`t say much, i was driving home from m...
# 3025   neutral                  well thats not nice... hope ur all good now
# 143   positive                                          that`s pretty funny
# 248   positive                                                    goodnight
# 2265  positive                                                          fun
# 875   negative                                               uncertainties.
# 1219  negative                                                          sad
# 2837  positive                                              good old ebay..
# 413   positive        i am definitely going to try and see up this weekend.
# 2477  negative                                                         miss
# 1701  positive                                                      welcome
# 1089  positive                                                         good
# 2850  negative   seagull hates me and im utterly depressed about it. i m...
# 1359  positive                                                     he loved
# 1083   neutral   i`m sure she`ll be fine. they`re not as daft as they lo...
# 494   positive                                                    hopefully
# 1728  negative                                                        weird

# %%
test.head(50)
# Out:
#         textID                                                         text  \
# 0   f87dea47db            Last session of the day  http://twitpic.com/67ezh
# 1   96d74cb729   Shanghai is also really exciting (precisely -- skyscrap...
# 2   eee518ae67  Recession hit Veronique Branquinho, she has to quit her ...
# 3   01082688c6                                                  happy bday!
# 4   33987a8ee5                       http://twitpic.com/4w75p - I like it!!
# 5   726e501993                              that`s great!! weee!! visitors!
# 6   261932614e                      I THINK EVERYONE HATES ME ON HERE   lol
# 7   afa11da83f   soooooo wish i could, but im in school and myspace is c...
# 8   e64208b4ef         and within a short time of the last clue all of them
# 9   37bcad24ca   What did you get?  My day is alright.. haven`t done any...
# 10  24c92644a4  My bike was put on hold...should have known that.... arg...
# 11  43b390b336                                    I checked.  We didn`t win
# 12  69d6b5d93e   .. and you`re on twitter! Did the tavern bore you that ...
# 13  5c1e0b61a1  I`m in VA for the weekend, my youngest son turns 2 tomor...
# 14  504e45d9d9  Its coming out the socket  I feel like my phones hole is...
# 15  ae93ad52a0  So hot today =_=  don`t like it and i hate my new timeta...
# 16  9fce30159a                                                     Miss you
# 17  00d5195223                                                 Cramps . . .
# 18  33f19050cf   you guys didn`t say hi or answer my questions yesterday...
# 19  f7718b3c23  I`m going into a spiritual stagnentation, its exploding ...
# 20  9ef44428d0                        Stupid storm. No river for us tonight
# 21  be634ebeb0        My dead grandpa pays more attention to me than you do
# 22  3dcf4f7e13    ... need retail therapy, bad. AHHH.....gimme money geebus
# 23  f0ef04109b                                         about to go to sleep
# 24  8be365118e                         you are lame  go make me breakfast!!
# 25  c50bdd4567                                                thats so cool
# 26  334954f215  hey peoples, dont you just hate being grounded haha, im ...
# 27  b783916431                        Huh, another ScarePoint coding Sunday
# 28  1fa8e6ad66   look who I found just for you  --->  http://twitter.com...
# 29  be38b29042  No AC, the fan doesnt swing our way ... we are sweating ...
# 30  95701e8ed9          guess that depends on if you want to be on the jury
# 31  4dd58ecd2c                          resorted to eating Mickey Ds ALONE.
# 32  cf553cccd5  There is a faux gothy chick looking at me, sorry I am no...
# 33  55c69c2d52               did he ask for your Twitter ID? Your sun sign?
# 34  9b1a52cc02                                              where`d you go!
# 35  cce5c4744a                            Watching Body of Lies...good film
# 36  c7f9d559e2                                 Happy mothers day mumm  xoxo
# 37  3d2478db59  So I really need to put the laptop down & start getting ...
# 38  6d846d7d50                             I`m sorry  at least it`s Friday?
# 39  599f51af6b  feels sorry every time I`m printing out, I use like 200 ...
# 40  87daa62920   4n? ma rog  never heard of it  esti beat acum? u tweet ...
# 41  6506dc55ff   I always forget SOMETHING when I travel. I am at Newark...
# 42  746d87f93e  Should have left car and walked home! I might need someo...
# 43  ef7ef8e474  i`m only updating this so that brett`s phone beeps  but ...
# 44  d3d7b13278   Hi there.  I agree!  Small children should be running a...
# 45  ddc07db84e                                 Hope ur havin fun in da club
# 46  67afe60d31  i miss my old phone it worked so good until i dropped it...
# 47  17d18ba9ef                                       thinks SG is wonderful
# 48  ab57d75f20    im really sorry i know wallah how u feel this life is ...
# 49  f0acd25d8e                                                    Not happy
#
#    sentiment                                                selected_text
# 0    neutral             last session of the day http://twitpic.com/67ezh
# 1   positive                                                     exciting
# 2   negative                                                such a shame!
# 3   positive                                                  happy bday!
# 4   positive                                                  i like it!!
# 5   positive                                               that`s great!!
# 6   negative                                                        hates
# 7   negative                                                      blocked
# 8    neutral         and within a short time of the last clue all of them
# 9    neutral   what did you get? my day is alright.. haven`t done anyt...
# 10  negative                                            argh total bummer
# 11   neutral                                     i checked. we didn`t win
# 12   neutral   .. and you`re on twitter! did the tavern bore you that ...
# 13  negative                                                         sad,
# 14  negative                                               loose it is...
# 15  negative                hate my new timetable, having such a bad week
# 16  negative                                                     miss you
# 17  negative                                                       cramps
# 18  positive                                                         nice
# 19   neutral   i`m going into a spiritual stagnentation, its exploding...
# 20  negative                                                       stupid
# 21  negative                                                      my dead
# 22  negative                                                         bad.
# 23   neutral                                         about to go to sleep
# 24  negative                                                         lame
# 25  positive                                                thats so cool
# 26   neutral   hey peoples, dont you just hate being grounded haha, im...
# 27   neutral                        huh, another scarepoint coding sunday
# 28  positive                                look who i found just for you
# 29  negative                           sweating it out on a hot humid day
# 30   neutral          guess that depends on if you want to be on the jury
# 31   neutral                          resorted to eating mickey ds alone.
# 32   neutral   there is a faux gothy chick looking at me, sorry i am n...
# 33   neutral               did he ask for your twitter id? your sun sign?
# 34   neutral                                              where`d you go!
# 35  positive                                                         good
# 36  positive                                                        happy
# 37   neutral   so i really need to put the laptop down & start getting...
# 38  negative                                                    i`m sorry
# 39  negative                                                  feels sorry
# 40  negative                                             u tweet too much
# 41   neutral   i always forget something when i travel. i am at newark...
# 42   neutral   should have left car and walked home! i might need some...
# 43   neutral   i`m only updating this so that brett`s phone beeps but ...
# 44  positive                                                       happy,
# 45  positive                                            hope ur havin fun
# 46   neutral   i miss my old phone it worked so good until i dropped i...
# 47  positive                                                    wonderful
# 48  negative                                                        sorry
# 49  negative                                                    not happy
